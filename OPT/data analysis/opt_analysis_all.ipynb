# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.stats import chi2
import scipy.constants as sc

from opt_analysis import analyze_optical_pumping_dataset

# %%
# experimental parameters

N = 135
R = 27.5e-2
h = 14.25e-2
z = 0.0

# %% [markdown]
# # $Rb^{85}$, B+

# %%
res_85_p = analyze_optical_pumping_dataset(
    filename="opt - Rb 85, +.csv",
    isotope="Rb85",
    field_direction="+",
    N=N, R=R, h=h, z=z,
    current_col=7,
    freq_col=0,
    current_err_col=8,   
    skiprows=1,
    rescale_errors=True,
    make_plots=True
)
# Out:
# === Rb85 + ===
# File: opt - Rb 85, +.csv
# Slope      = 2.0467 ± 0.0211 MHz/A
# Intercept  = 0.1650 ± 0.0215 MHz
# chi^2      = 9.000
# dof        = 9
# chi^2/dof  = 1.000
# p-value    = 0.4373
# scale fac. = 1.2605
# B_amb      = 0.3537 ± 0.0461 G
# I_fit      = 2.4524 ± 0.0305

# %% [markdown]
# # $Rb^{85}$, B-

# %%
res_85_m = analyze_optical_pumping_dataset(
    filename="opt - Rb 85, -.csv",
    isotope="Rb85",
    field_direction="-",
    N=N, R=R, h=h, z=z,
    current_col=7,
    freq_col=0,
    current_err_col=8,
    skiprows=1,
    rescale_errors=True,
    make_plots=True
)
# Out:
# === Rb85 - ===
# File: opt - Rb 85, -.csv
# Slope      = -2.0334 ± 0.0312 MHz/A
# Intercept  = -0.1924 ± 0.0427 MHz
# chi^2      = 9.000
# dof        = 9
# chi^2/dof  = 1.000
# p-value    = 0.4373
# scale fac. = 1.3118
# B_amb      = -0.4124 ± 0.0915 G
# I_fit      = 2.4718 ± 0.0456

# %% [markdown]
# # $Rb^{87}$, B+

# %%
res_87_p = analyze_optical_pumping_dataset(
    filename="opt - Rb 87, +.csv",
    isotope="Rb87",
    field_direction="+",
    N=N, R=R, h=h, z=z,
    current_col=7,
    freq_col=0,
    current_err_col=8,   
    skiprows=1,
    rescale_errors=True,
    make_plots=True
)
# Out:
# === Rb87 + ===
# File: opt - Rb 87, +.csv
# Slope      = 3.1368 ± 0.1106 MHz/A
# Intercept  = 0.1507 ± 0.1129 MHz
# chi^2      = 9.000
# dof        = 9
# chi^2/dof  = 1.000
# p-value    = 0.4373
# scale fac. = 8.1679
# B_amb      = 0.2153 ± 0.1614 G
# I_fit      = 1.4264 ± 0.0679

# %% [markdown]
# # $Rb^{87}$, B-

# %%
res_87_m = analyze_optical_pumping_dataset(
    filename="opt - Rb 87, -.csv",
    isotope="Rb87",
    field_direction="-",
    N=N, R=R, h=h, z=z,
    current_col=7,
    freq_col=0,
    current_err_col=8,
    skiprows=1,
    rescale_errors=True,
    make_plots=True
)
# Out:
# === Rb87 - ===
# File: opt - Rb 87, -.csv
# Slope      = -3.0328 ± 0.0095 MHz/A
# Intercept  = -0.2698 ± 0.0122 MHz
# chi^2      = 9.000
# dof        = 9
# chi^2/dof  = 1.000
# p-value    = 0.4373
# scale fac. = 0.4083
# B_amb      = -0.3856 ± 0.0175 G
# I_fit      = 1.4925 ± 0.0062
